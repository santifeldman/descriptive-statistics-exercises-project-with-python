# %% [markdown]
# # Descriptive statistics problems

# %% [markdown]
# ### Exercise 1
#
# We will use NumPy to obtain information to describe statistically.
#
# - Generate an array of 100 elements following a normal distribution.
# - Generate an array of 100 elements following a chi-square distribution with 3 degrees of freedom.
# - Calculate the main metrics and statistical measures that best describe the two vectors.

# %%
# TODO
import numpy as np
import statistics as stats
from scipy.stats import kurtosis
from scipy.stats import skew

array1 = np.random.normal (loc=0.0, scale=1.0, size=100)
media = stats.mean(array1)
mediana = stats.median(array1)
mode=stats.mode(array1)
variance = stats.variance(array1)
std = stats.stdev(array1)
skewness = skew(array1)
kurt = kurtosis(array1)
print (array1)
print(f'La media del array es de {media}, la mediana es de {mediana} y la moda de {mode}')
print (f'La varianza del array es de {variance}, mientras que el desvio estandar es {std}')

array2=np.random.chisquare(df=3,size=100)
mean1=stats.mean(array2)
median1=stats.median(array2)
mode1=stats.mode(array2)
variance = stats.variance(array2)
std = stats.stdev(array2)
skewness = skew(array2)
kurt = kurtosis(array2)
print (array2)
print(f'La media del array es de {media}, la mediana es de {mediana} y la moda de {mode}')
print (f'La varianza del array es de {variance}, mientras que el desvio estandar es {std}')
# Out:
# [ 0.48491539  1.5043098  -0.54216897 -0.66948541  0.39388752 -0.16627143
#  -0.60435594 -1.72364388  0.16809437  0.29656762 -1.37364349  1.28598339
#  -0.74743537 -1.59902502 -0.99183704  0.73093645  0.76920247 -0.59732753
#  -1.02968849  0.96364229 -0.09044847 -0.77849874 -0.1854335  -0.45213298
#  -0.27542337 -0.01994173  1.35481809 -0.5406185  -0.34839754 -1.428511
#   1.13024482 -1.00418688 -0.33430743  0.22051839 -0.05623279 -1.13603594
#  -0.55206334  0.18817449  0.91208928  0.44819804  2.05586949  1.12153508
#   0.97426534 -0.96065413 -0.6416961   1.07622729 -1.13085824  0.14267203
#   0.9096753   1.41119385 -0.43614948 -0.7338078   0.97515728  0.24004933
#  -2.14626565  1.14246107 -2.30569648  0.60741465  0.13110083 -0.35936249
#  -0.86979203  1.0093233  -1.1937935   0.17918132 -0.94406539  0.57815809
#  -0.15823481  1.11785498  0.60842335 -1.63504782  0.343508   -0.54414485
#  -0.33368971 -0.85082871 -0.33681985  0.79623231 -1.42548437  0.38763256
# ...

# %%
import numpy as np
import statistics as stats
from scipy.stats import kurtosis, skew

def calculate_statistics(array):
    statistics = {
        'media': stats.mean(array),
        'mediana': stats.median(array),
        'moda': stats.mode(array),
        'varianza': stats.variance(array),
        'desvio estandar': stats.stdev(array),
        'asimetria': skew(array),
        'curtosis': kurtosis(array)
    }
    return statistics

def print_statistics(statistics, array_name):
    print(f'Estadísticas para {array_name}:')
    print(f"La media del array es de {statistics['media']}")
    print(f"La mediana es de {statistics['mediana']}")
    print(f"La moda es de {statistics['moda']}")
    print(f"La varianza del array es de {statistics['varianza']}")
    print(f"El desvio estandar es {statistics['desvio estandar']}")
    print(f"La asimetria es de {statistics['asimetria']}")
    print(f"La curtosis es de {statistics['curtosis']}")
    print()

# Generar array1 con distribución normal
array1 = np.random.normal(loc=0.0, scale=1.0, size=100)
stats_array1 = calculate_statistics(array1)
print(array1)
print_statistics(stats_array1, "array1")

# Generar array2 con distribución chi-cuadrado
array2 = np.random.chisquare(df=3, size=100)
stats_array2 = calculate_statistics(array2)
print(array2)
print_statistics(stats_array2, "array2")
# Out:
# [-0.80986899 -0.22009327 -1.56488399 -0.65690566 -0.16060363 -1.87932704
#  -0.85290377  0.24256134 -0.8939756  -1.25253685 -0.41976778  1.00155691
#  -1.65202415  0.53899243  0.84006392  0.06938782 -0.23630372 -0.57430423
#   0.75042151  0.99654954  0.35439752  0.15915456 -1.5323802   0.45404427
#   0.58664526 -0.89797522 -1.01653464 -1.22646423 -1.01731979 -0.99022773
#   1.77918782 -0.38146803 -0.01054333 -0.49308239  0.38019395  0.15496074
#  -0.77437159 -0.32747089 -1.30371343  0.8681023   0.55543824  0.07813568
#  -0.33761046 -0.53723676 -0.20180694  0.1041636   0.15480521 -0.11117823
#   0.30329151 -1.30945855  0.90726969 -0.00769409 -0.16916274  1.83402001
#   0.14684848  1.10023781 -0.43811717 -0.88944402 -0.53592064  0.3828931
#  -0.73029391 -0.77424539 -0.91630404  1.52864566 -0.18824045 -1.03588753
#  -0.30049936 -0.1209714  -0.48001633 -1.32272074  0.53852825  1.00285778
#  -0.02490359 -0.08225855 -0.93852976 -0.46357334 -1.27586314 -0.01086454
# ...

# %% [markdown]
# ### Exercise 2
#
# Write a Python program to calculate the standard deviation of the following data:
#
# ```py
# data = [4, 2, 5, 8, 6]
# ```

# %%
# TODO
import statistics as stats  
data = [4,2,5,8,6]
std = stats.stdev(data)
print(f"Desviación estándar: {std}")


import math
def calcular_media(data):
    return sum(data) / len(data)

def calcular_desvio_estandar(data):
    media = calcular_media(data)
    varianza = sum((x - media) ** 2 for x in data) / (len(data) -1)
    desvio_estandar = math.sqrt(varianza)
    return desvio_estandar

desvio_estandar = calcular_desvio_estandar(data)
print (desvio_estandar)
# Out:
# Desviación estándar: 2.23606797749979
# 2.23606797749979
